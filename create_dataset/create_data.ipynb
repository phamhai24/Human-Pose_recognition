# %%
# !pip install mediapipe

# %%
import cv2
import mediapipe as mp
import pandas as pd
import time
import os

# Khởi tạo thư viện MediaPipe
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_draw = mp.solutions.drawing_utils

# Mở webcam
cap = cv2.VideoCapture(0)

# Danh sách hành động cần thu thập
actions = ["ngoi_lam_viec", "ngoi_nga_lung", "nam_ngu", "gac_chan", "dung_day", "di_lai"]
data = {action: [] for action in actions}
current_label = None  # Mặc định không ghi dữ liệu
recording = False  # Cờ kiểm soát trạng thái ghi

# Số khung hình cần thu thập mỗi hành động
no_of_frames = 600
frame_count = {action: 0 for action in actions}  # Đếm số frame đã thu thập
fps_limit = 60  # Giới hạn FPS
prev_time = 0

def extract_landmarks(results):
    """Trích xuất thông số khung xương từ MediaPipe."""
    if results.pose_landmarks:
        return [coord for lm in results.pose_landmarks.landmark for coord in (lm.x, lm.y, lm.z, lm.visibility)]
    return []

print("Nhấn số để bắt đầu ghi hành động:")
print("1: Ngồi làm việc | 2: Ngồi ngả lưng | 3: Nằm ngủ | 4: Gác chân | 5: Đứng dậy | 6: Đi lại | SPACE: Dừng ghi | Q: Thoát ")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Giới hạn tốc độ FPS
    curr_time = time.time()
    if curr_time - prev_time < 1 / fps_limit:
        continue
    prev_time = curr_time

    # Xử lý ảnh với MediaPipe
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(frame_rgb)

    # Nếu đang ghi, trích xuất dữ liệu
    if recording and current_label is not None:
        lm = extract_landmarks(results)
        if lm:
            data[current_label].append(lm)
            frame_count[current_label] += 1  # Tăng số frame đã thu thập
            print(f"Đang ghi '{current_label.upper()}': {frame_count[current_label]}/{no_of_frames} frames")

            # Hiển thị trạng thái ghi dữ liệu trên màn hình
            cv2.putText(frame, f"Recording: {current_label.upper()} ({frame_count[current_label]}/{no_of_frames})",
                        (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

            # Nếu đủ 600 frames thì tự động dừng ghi
            if frame_count[current_label] >= no_of_frames:
                print(f"Đã thu thập đủ {no_of_frames} frames cho '{current_label.upper()}'!")
                recording = False

    # Vẽ khung xương lên ảnh
    if results.pose_landmarks:
        mp_draw.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                               mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=4),
                               mp_draw.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=4))

    # Hiển thị thông tin hành động hiện tại
    if current_label:
        cv2.putText(frame, f"Label: {current_label.upper()}", (10, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Hiển thị hình ảnh
    cv2.imshow("Pose Detection", frame)

    # Chuyển đổi hành động khi nhấn phím
    key = cv2.waitKey(1) & 0xFF
    if key == ord('1'):
        current_label = "ngoi_lam_viec"
        recording = True
    elif key == ord('2'):
        current_label = "ngoi_nga_lung"
        recording = True
    elif key == ord('3'):
        current_label = "nam_ngu"
        recording = True
    elif key == ord('4'):
        current_label = "gac_chan"
        recording = True
    elif key == ord('5'):
        current_label = "dung_day"
        recording = True
    elif key == ord('6'):
        current_label = "di_lai"
        recording = True
    elif key == ord(' '):  # Nhấn SPACE để dừng ghi
        recording = False
        print(f"⏸ Dừng ghi hành động '{current_label.upper()}'")
    elif key == ord('q'):
        break

# Lưu dữ liệu vào file CSV 
for action, lm_list in data.items():
    if lm_list:
        filename = f"{action}.csv"
        df = pd.DataFrame(lm_list)

        # Nếu file đã tồn tại, append dữ liệu vào
        if os.path.exists(filename):
            df.to_csv(filename, mode='a', header=False, index=False)
        else:
            df.to_csv(filename, index=False)

print("Dữ liệu đã lưu thành công!")
cap.release()
cv2.destroyAllWindows()
# Out:
# Nhấn số để bắt đầu ghi hành động:
# 1: Ngồi làm việc | 2: Ngồi ngả lưng | 3: Nằm ngủ | 4: Gác chân | 5: Đứng dậy | 6: Đi lại | SPACE: Dừng ghi | Q: Thoát
# Đang ghi 'DI_LAI': 1/600 frames
# Đang ghi 'DI_LAI': 2/600 frames
# Đang ghi 'DI_LAI': 3/600 frames
# Đang ghi 'DI_LAI': 4/600 frames
# Đang ghi 'DI_LAI': 5/600 frames
# Đang ghi 'DI_LAI': 6/600 frames
# Đang ghi 'DI_LAI': 7/600 frames
# Đang ghi 'DI_LAI': 8/600 frames
# Đang ghi 'DI_LAI': 9/600 frames
# Đang ghi 'DI_LAI': 10/600 frames
# Đang ghi 'DI_LAI': 11/600 frames
# Đang ghi 'DI_LAI': 12/600 frames
# Đang ghi 'DI_LAI': 13/600 frames
# Đang ghi 'DI_LAI': 14/600 frames
# Đang ghi 'DI_LAI': 15/600 frames
# Đang ghi 'DI_LAI': 16/600 frames
# Đang ghi 'DI_LAI': 17/600 frames
# Đang ghi 'DI_LAI': 18/600 frames
# Đang ghi 'DI_LAI': 19/600 frames
# Đang ghi 'DI_LAI': 20/600 frames
# Đang ghi 'DI_LAI': 21/600 frames
# Đang ghi 'DI_LAI': 22/600 frames
# Đang ghi 'DI_LAI': 23/600 frames
# Đang ghi 'DI_LAI': 24/600 frames
# Đang ghi 'DI_LAI': 25/600 frames
# Đang ghi 'DI_LAI': 26/600 frames
# Đang ghi 'DI_LAI': 27/600 frames
# Đang ghi 'DI_LAI': 28/600 frames
# Đang ghi 'DI_LAI': 29/600 frames
# Đang ghi 'DI_LAI': 30/600 frames
# Đang ghi 'DI_LAI': 31/600 frames
# Đang ghi 'DI_LAI': 32/600 frames
# Đang ghi 'DI_LAI': 33/600 frames
# Đang ghi 'DI_LAI': 34/600 frames
# Đang ghi 'DI_LAI': 35/600 frames
# Đang ghi 'DI_LAI': 36/600 frames
# Đang ghi 'DI_LAI': 37/600 frames
# Đang ghi 'DI_LAI': 38/600 frames
# Đang ghi 'DI_LAI': 39/600 frames
# Đang ghi 'DI_LAI': 40/600 frames
# Đang ghi 'DI_LAI': 41/600 frames
# Đang ghi 'DI_LAI': 42/600 frames
# Đang ghi 'DI_LAI': 43/600 frames
# Đang ghi 'DI_LAI': 44/600 frames
# Đang ghi 'DI_LAI': 45/600 frames
# Đang ghi 'DI_LAI': 46/600 frames
# Đang ghi 'DI_LAI': 47/600 frames
# Đang ghi 'DI_LAI': 48/600 frames
# Đang ghi 'DI_LAI': 49/600 frames
# Đang ghi 'DI_LAI': 50/600 frames
# Đang ghi 'DI_LAI': 51/600 frames
# Đang ghi 'DI_LAI': 52/600 frames
# Đang ghi 'DI_LAI': 53/600 frames
# Đang ghi 'DI_LAI': 54/600 frames
# Đang ghi 'DI_LAI': 55/600 frames
# Đang ghi 'DI_LAI': 56/600 frames
# Đang ghi 'DI_LAI': 57/600 frames
# Đang ghi 'DI_LAI': 58/600 frames
# Đang ghi 'DI_LAI': 59/600 frames
# Đang ghi 'DI_LAI': 60/600 frames
# Đang ghi 'DI_LAI': 61/600 frames
# Đang ghi 'DI_LAI': 62/600 frames
# Đang ghi 'DI_LAI': 63/600 frames
# Đang ghi 'DI_LAI': 64/600 frames
# Đang ghi 'DI_LAI': 65/600 frames
# Đang ghi 'DI_LAI': 66/600 frames
# Đang ghi 'DI_LAI': 67/600 frames
# Đang ghi 'DI_LAI': 68/600 frames
# Đang ghi 'DI_LAI': 69/600 frames
# Đang ghi 'DI_LAI': 70/600 frames
# Đang ghi 'DI_LAI': 71/600 frames
# Đang ghi 'DI_LAI': 72/600 frames
# Đang ghi 'DI_LAI': 73/600 frames
# Đang ghi 'DI_LAI': 74/600 frames
# Đang ghi 'DI_LAI': 75/600 frames
# Đang ghi 'DI_LAI': 76/600 frames
# Đang ghi 'DI_LAI': 77/600 frames
# Đang ghi 'DI_LAI': 78/600 frames
# Đang ghi 'DI_LAI': 79/600 frames
# Đang ghi 'DI_LAI': 80/600 frames
# Đang ghi 'DI_LAI': 81/600 frames
# Đang ghi 'DI_LAI': 82/600 frames
# Đang ghi 'DI_LAI': 83/600 frames
# Đang ghi 'DI_LAI': 84/600 frames
# Đang ghi 'DI_LAI': 85/600 frames
# Đang ghi 'DI_LAI': 86/600 frames
# Đang ghi 'DI_LAI': 87/600 frames
# Đang ghi 'DI_LAI': 88/600 frames
# Đang ghi 'DI_LAI': 89/600 frames
# Đang ghi 'DI_LAI': 90/600 frames
# Đang ghi 'DI_LAI': 91/600 frames
# Đang ghi 'DI_LAI': 92/600 frames
# Đang ghi 'DI_LAI': 93/600 frames
# Đang ghi 'DI_LAI': 94/600 frames
# Đang ghi 'DI_LAI': 95/600 frames
# Đang ghi 'DI_LAI': 96/600 frames
# Đang ghi 'DI_LAI': 97/600 frames
# Đang ghi 'DI_LAI': 98/600 frames
# Đang ghi 'DI_LAI': 99/600 frames
# Đang ghi 'DI_LAI': 100/600 frames
# Đang ghi 'DI_LAI': 101/600 frames
# Đang ghi 'DI_LAI': 102/600 frames
# Đang ghi 'DI_LAI': 103/600 frames
# Đang ghi 'DI_LAI': 104/600 frames
# Đang ghi 'DI_LAI': 105/600 frames
# Đang ghi 'DI_LAI': 106/600 frames
# Đang ghi 'DI_LAI': 107/600 frames
# Đang ghi 'DI_LAI': 108/600 frames
# Đang ghi 'DI_LAI': 109/600 frames
# Đang ghi 'DI_LAI': 110/600 frames
# Đang ghi 'DI_LAI': 111/600 frames
# Đang ghi 'DI_LAI': 112/600 frames
# Đang ghi 'DI_LAI': 113/600 frames
# Đang ghi 'DI_LAI': 114/600 frames
# Đang ghi 'DI_LAI': 115/600 frames
# Đang ghi 'DI_LAI': 116/600 frames
# Đang ghi 'DI_LAI': 117/600 frames
# Đang ghi 'DI_LAI': 118/600 frames
# Đang ghi 'DI_LAI': 119/600 frames
# Đang ghi 'DI_LAI': 120/600 frames
# Đang ghi 'DI_LAI': 121/600 frames
# Đang ghi 'DI_LAI': 122/600 frames
# Đang ghi 'DI_LAI': 123/600 frames
# Đang ghi 'DI_LAI': 124/600 frames
# Đang ghi 'DI_LAI': 125/600 frames
# Đang ghi 'DI_LAI': 126/600 frames
# Đang ghi 'DI_LAI': 127/600 frames
# Đang ghi 'DI_LAI': 128/600 frames
# Đang ghi 'DI_LAI': 129/600 frames
# Đang ghi 'DI_LAI': 130/600 frames
# Đang ghi 'DI_LAI': 131/600 frames
# Đang ghi 'DI_LAI': 132/600 frames
# Đang ghi 'DI_LAI': 133/600 frames
# Đang ghi 'DI_LAI': 134/600 frames
# Đang ghi 'DI_LAI': 135/600 frames
# Đang ghi 'DI_LAI': 136/600 frames
# Đang ghi 'DI_LAI': 137/600 frames
# Đang ghi 'DI_LAI': 138/600 frames
# Đang ghi 'DI_LAI': 139/600 frames
# Đang ghi 'DI_LAI': 140/600 frames
# Đang ghi 'DI_LAI': 141/600 frames
# Đang ghi 'DI_LAI': 142/600 frames
# Đang ghi 'DI_LAI': 143/600 frames
# Đang ghi 'DI_LAI': 144/600 frames
# Đang ghi 'DI_LAI': 145/600 frames
# Đang ghi 'DI_LAI': 146/600 frames
# Đang ghi 'DI_LAI': 147/600 frames
# Đang ghi 'DI_LAI': 148/600 frames
# Đang ghi 'DI_LAI': 149/600 frames
# Đang ghi 'DI_LAI': 150/600 frames
# Đang ghi 'DI_LAI': 151/600 frames
# Đang ghi 'DI_LAI': 152/600 frames
# Đang ghi 'DI_LAI': 153/600 frames
# Đang ghi 'DI_LAI': 154/600 frames
# Đang ghi 'DI_LAI': 155/600 frames
# Đang ghi 'DI_LAI': 156/600 frames
# Đang ghi 'DI_LAI': 157/600 frames
# Đang ghi 'DI_LAI': 158/600 frames
# Đang ghi 'DI_LAI': 159/600 frames
# Đang ghi 'DI_LAI': 160/600 frames
# Đang ghi 'DI_LAI': 161/600 frames
# Đang ghi 'DI_LAI': 162/600 frames
# Đang ghi 'DI_LAI': 163/600 frames
# Đang ghi 'DI_LAI': 164/600 frames
# Đang ghi 'DI_LAI': 165/600 frames
# Đang ghi 'DI_LAI': 166/600 frames
# Đang ghi 'DI_LAI': 167/600 frames
# Đang ghi 'DI_LAI': 168/600 frames
# Đang ghi 'DI_LAI': 169/600 frames
# Đang ghi 'DI_LAI': 170/600 frames
# Đang ghi 'DI_LAI': 171/600 frames
# Đang ghi 'DI_LAI': 172/600 frames
# Đang ghi 'DI_LAI': 173/600 frames
# Đang ghi 'DI_LAI': 174/600 frames
# Đang ghi 'DI_LAI': 175/600 frames
# Đang ghi 'DI_LAI': 176/600 frames
# Đang ghi 'DI_LAI': 177/600 frames
# Đang ghi 'DI_LAI': 178/600 frames
# Đang ghi 'DI_LAI': 179/600 frames
# Đang ghi 'DI_LAI': 180/600 frames
# Đang ghi 'DI_LAI': 181/600 frames
# Đang ghi 'DI_LAI': 182/600 frames
# Đang ghi 'DI_LAI': 183/600 frames
# Đang ghi 'DI_LAI': 184/600 frames
# Đang ghi 'DI_LAI': 185/600 frames
# Đang ghi 'DI_LAI': 186/600 frames
# Đang ghi 'DI_LAI': 187/600 frames
# Đang ghi 'DI_LAI': 188/600 frames
# Đang ghi 'DI_LAI': 189/600 frames
# Đang ghi 'DI_LAI': 190/600 frames
# Đang ghi 'DI_LAI': 191/600 frames
# Đang ghi 'DI_LAI': 192/600 frames
# Đang ghi 'DI_LAI': 193/600 frames
# Đang ghi 'DI_LAI': 194/600 frames
# Đang ghi 'DI_LAI': 195/600 frames
# Đang ghi 'DI_LAI': 196/600 frames
# Đang ghi 'DI_LAI': 197/600 frames
# Đang ghi 'DI_LAI': 198/600 frames
# Đang ghi 'DI_LAI': 199/600 frames
# Đang ghi 'DI_LAI': 200/600 frames
# Đang ghi 'DI_LAI': 201/600 frames
# Đang ghi 'DI_LAI': 202/600 frames
# Đang ghi 'DI_LAI': 203/600 frames
# Đang ghi 'DI_LAI': 204/600 frames
# Đang ghi 'DI_LAI': 205/600 frames
# Đang ghi 'DI_LAI': 206/600 frames
# Đang ghi 'DI_LAI': 207/600 frames
# Đang ghi 'DI_LAI': 208/600 frames
# Đang ghi 'DI_LAI': 209/600 frames
# Đang ghi 'DI_LAI': 210/600 frames
# Đang ghi 'DI_LAI': 211/600 frames
# Đang ghi 'DI_LAI': 212/600 frames
# Đang ghi 'DI_LAI': 213/600 frames
# Đang ghi 'DI_LAI': 214/600 frames
# Đang ghi 'DI_LAI': 215/600 frames
# Đang ghi 'DI_LAI': 216/600 frames
# Đang ghi 'DI_LAI': 217/600 frames
# Đang ghi 'DI_LAI': 218/600 frames
# Đang ghi 'DI_LAI': 219/600 frames
# Đang ghi 'DI_LAI': 220/600 frames
# Đang ghi 'DI_LAI': 221/600 frames
# Đang ghi 'DI_LAI': 222/600 frames
# Đang ghi 'DI_LAI': 223/600 frames
# Đang ghi 'DI_LAI': 224/600 frames
# Đang ghi 'DI_LAI': 225/600 frames
# Đang ghi 'DI_LAI': 226/600 frames
# Đang ghi 'DI_LAI': 227/600 frames
# Đang ghi 'DI_LAI': 228/600 frames
# Đang ghi 'DI_LAI': 229/600 frames
# Đang ghi 'DI_LAI': 230/600 frames
# Đang ghi 'DI_LAI': 231/600 frames
# Đang ghi 'DI_LAI': 232/600 frames
# Đang ghi 'DI_LAI': 233/600 frames
# Đang ghi 'DI_LAI': 234/600 frames
# Đang ghi 'DI_LAI': 235/600 frames
# Đang ghi 'DI_LAI': 236/600 frames
# Đang ghi 'DI_LAI': 237/600 frames
# Đang ghi 'DI_LAI': 238/600 frames
# Đang ghi 'DI_LAI': 239/600 frames
# Đang ghi 'DI_LAI': 240/600 frames
# Đang ghi 'DI_LAI': 241/600 frames
# Đang ghi 'DI_LAI': 242/600 frames
# Đang ghi 'DI_LAI': 243/600 frames
# Đang ghi 'DI_LAI': 244/600 frames
# Đang ghi 'DI_LAI': 245/600 frames
# Đang ghi 'DI_LAI': 246/600 frames
# Đang ghi 'DI_LAI': 247/600 frames
# Đang ghi 'DI_LAI': 248/600 frames
# Đang ghi 'DI_LAI': 249/600 frames
# Đang ghi 'DI_LAI': 250/600 frames
# Đang ghi 'DI_LAI': 251/600 frames
# Đang ghi 'DI_LAI': 252/600 frames
# Đang ghi 'DI_LAI': 253/600 frames
# Đang ghi 'DI_LAI': 254/600 frames
# Đang ghi 'DI_LAI': 255/600 frames
# Đang ghi 'DI_LAI': 256/600 frames
# Đang ghi 'DI_LAI': 257/600 frames
# Đang ghi 'DI_LAI': 258/600 frames
# Đang ghi 'DI_LAI': 259/600 frames
# Đang ghi 'DI_LAI': 260/600 frames
# Đang ghi 'DI_LAI': 261/600 frames
# Đang ghi 'DI_LAI': 262/600 frames
# Đang ghi 'DI_LAI': 263/600 frames
# Đang ghi 'DI_LAI': 264/600 frames
# Đang ghi 'DI_LAI': 265/600 frames
# Đang ghi 'DI_LAI': 266/600 frames
# Đang ghi 'DI_LAI': 267/600 frames
# Đang ghi 'DI_LAI': 268/600 frames
# Đang ghi 'DI_LAI': 269/600 frames
# Đang ghi 'DI_LAI': 270/600 frames
# Đang ghi 'DI_LAI': 271/600 frames
# Đang ghi 'DI_LAI': 272/600 frames
# Đang ghi 'DI_LAI': 273/600 frames
# Đang ghi 'DI_LAI': 274/600 frames
# Đang ghi 'DI_LAI': 275/600 frames
# Đang ghi 'DI_LAI': 276/600 frames
# Đang ghi 'DI_LAI': 277/600 frames
# Đang ghi 'DI_LAI': 278/600 frames
# Đang ghi 'DI_LAI': 279/600 frames
# Đang ghi 'DI_LAI': 280/600 frames
# Đang ghi 'DI_LAI': 281/600 frames
# Đang ghi 'DI_LAI': 282/600 frames
# Đang ghi 'DI_LAI': 283/600 frames
# Đang ghi 'DI_LAI': 284/600 frames
# Đang ghi 'DI_LAI': 285/600 frames
# Đang ghi 'DI_LAI': 286/600 frames
# Đang ghi 'DI_LAI': 287/600 frames
# Đang ghi 'DI_LAI': 288/600 frames
# Đang ghi 'DI_LAI': 289/600 frames
# Đang ghi 'DI_LAI': 290/600 frames
# Đang ghi 'DI_LAI': 291/600 frames
# Đang ghi 'DI_LAI': 292/600 frames
# Đang ghi 'DI_LAI': 293/600 frames
# Đang ghi 'DI_LAI': 294/600 frames
# Đang ghi 'DI_LAI': 295/600 frames
# Đang ghi 'DI_LAI': 296/600 frames
# Đang ghi 'DI_LAI': 297/600 frames
# Đang ghi 'DI_LAI': 298/600 frames
# Đang ghi 'DI_LAI': 299/600 frames
# Đang ghi 'DI_LAI': 300/600 frames
# Đang ghi 'DI_LAI': 301/600 frames
# Đang ghi 'DI_LAI': 302/600 frames
# Đang ghi 'DI_LAI': 303/600 frames
# Đang ghi 'DI_LAI': 304/600 frames
# Đang ghi 'DI_LAI': 305/600 frames
# Đang ghi 'DI_LAI': 306/600 frames
# Đang ghi 'DI_LAI': 307/600 frames
# Đang ghi 'DI_LAI': 308/600 frames
# Đang ghi 'DI_LAI': 309/600 frames
# Đang ghi 'DI_LAI': 310/600 frames
# Đang ghi 'DI_LAI': 311/600 frames
# Đang ghi 'DI_LAI': 312/600 frames
# Đang ghi 'DI_LAI': 313/600 frames
# Đang ghi 'DI_LAI': 314/600 frames
# Đang ghi 'DI_LAI': 315/600 frames
# Đang ghi 'DI_LAI': 316/600 frames
# Đang ghi 'DI_LAI': 317/600 frames
# Đang ghi 'DI_LAI': 318/600 frames
# Đang ghi 'DI_LAI': 319/600 frames
# Đang ghi 'DI_LAI': 320/600 frames
# Đang ghi 'DI_LAI': 321/600 frames
# Đang ghi 'DI_LAI': 322/600 frames
# Đang ghi 'DI_LAI': 323/600 frames
# Đang ghi 'DI_LAI': 324/600 frames
# Đang ghi 'DI_LAI': 325/600 frames
# Đang ghi 'DI_LAI': 326/600 frames
# Đang ghi 'DI_LAI': 327/600 frames
# Đang ghi 'DI_LAI': 328/600 frames
# Đang ghi 'DI_LAI': 329/600 frames
# Đang ghi 'DI_LAI': 330/600 frames
# Đang ghi 'DI_LAI': 331/600 frames
# Đang ghi 'DI_LAI': 332/600 frames
# Đang ghi 'DI_LAI': 333/600 frames
# Đang ghi 'DI_LAI': 334/600 frames
# Đang ghi 'DI_LAI': 335/600 frames
# Đang ghi 'DI_LAI': 336/600 frames
# Đang ghi 'DI_LAI': 337/600 frames
# Đang ghi 'DI_LAI': 338/600 frames
# Đang ghi 'DI_LAI': 339/600 frames
# Đang ghi 'DI_LAI': 340/600 frames
# Đang ghi 'DI_LAI': 341/600 frames
# Đang ghi 'DI_LAI': 342/600 frames
# Đang ghi 'DI_LAI': 343/600 frames
# Đang ghi 'DI_LAI': 344/600 frames
# Đang ghi 'DI_LAI': 345/600 frames
# Đang ghi 'DI_LAI': 346/600 frames
# Đang ghi 'DI_LAI': 347/600 frames
# Đang ghi 'DI_LAI': 348/600 frames
# Đang ghi 'DI_LAI': 349/600 frames
# Đang ghi 'DI_LAI': 350/600 frames
# Đang ghi 'DI_LAI': 351/600 frames
# Đang ghi 'DI_LAI': 352/600 frames
# Đang ghi 'DI_LAI': 353/600 frames
# Đang ghi 'DI_LAI': 354/600 frames
# Đang ghi 'DI_LAI': 355/600 frames
# Đang ghi 'DI_LAI': 356/600 frames
# Đang ghi 'DI_LAI': 357/600 frames
# Đang ghi 'DI_LAI': 358/600 frames
# Đang ghi 'DI_LAI': 359/600 frames
# Đang ghi 'DI_LAI': 360/600 frames
# Đang ghi 'DI_LAI': 361/600 frames
# Đang ghi 'DI_LAI': 362/600 frames
# Đang ghi 'DI_LAI': 363/600 frames
# Đang ghi 'DI_LAI': 364/600 frames
# Đang ghi 'DI_LAI': 365/600 frames
# Đang ghi 'DI_LAI': 366/600 frames
# Đang ghi 'DI_LAI': 367/600 frames
# Đang ghi 'DI_LAI': 368/600 frames
# Đang ghi 'DI_LAI': 369/600 frames
# Đang ghi 'DI_LAI': 370/600 frames
# Đang ghi 'DI_LAI': 371/600 frames
# Đang ghi 'DI_LAI': 372/600 frames
# Đang ghi 'DI_LAI': 373/600 frames
# Đang ghi 'DI_LAI': 374/600 frames
# Đang ghi 'DI_LAI': 375/600 frames
# Đang ghi 'DI_LAI': 376/600 frames
# Đang ghi 'DI_LAI': 377/600 frames
# Đang ghi 'DI_LAI': 378/600 frames
# Đang ghi 'DI_LAI': 379/600 frames
# Đang ghi 'DI_LAI': 380/600 frames
# Đang ghi 'DI_LAI': 381/600 frames
# Đang ghi 'DI_LAI': 382/600 frames
# Đang ghi 'DI_LAI': 383/600 frames
# Đang ghi 'DI_LAI': 384/600 frames
# Đang ghi 'DI_LAI': 385/600 frames
# Đang ghi 'DI_LAI': 386/600 frames
# Đang ghi 'DI_LAI': 387/600 frames
# Đang ghi 'DI_LAI': 388/600 frames
# Đang ghi 'DI_LAI': 389/600 frames
# Đang ghi 'DI_LAI': 390/600 frames
# Đang ghi 'DI_LAI': 391/600 frames
# Đang ghi 'DI_LAI': 392/600 frames
# Đang ghi 'DI_LAI': 393/600 frames
# Đang ghi 'DI_LAI': 394/600 frames
# Đang ghi 'DI_LAI': 395/600 frames
# Đang ghi 'DI_LAI': 396/600 frames
# Đang ghi 'DI_LAI': 397/600 frames
# Đang ghi 'DI_LAI': 398/600 frames
# Đang ghi 'DI_LAI': 399/600 frames
# Đang ghi 'DI_LAI': 400/600 frames
# Đang ghi 'DI_LAI': 401/600 frames
# Đang ghi 'DI_LAI': 402/600 frames
# Đang ghi 'DI_LAI': 403/600 frames
# Đang ghi 'DI_LAI': 404/600 frames
# Đang ghi 'DI_LAI': 405/600 frames
# Đang ghi 'DI_LAI': 406/600 frames
# Đang ghi 'DI_LAI': 407/600 frames
# Đang ghi 'DI_LAI': 408/600 frames
# Đang ghi 'DI_LAI': 409/600 frames
# Đang ghi 'DI_LAI': 410/600 frames
# Đang ghi 'DI_LAI': 411/600 frames
# Đang ghi 'DI_LAI': 412/600 frames
# Đang ghi 'DI_LAI': 413/600 frames
# Đang ghi 'DI_LAI': 414/600 frames
# Đang ghi 'DI_LAI': 415/600 frames
# Đang ghi 'DI_LAI': 416/600 frames
# Đang ghi 'DI_LAI': 417/600 frames
# Đang ghi 'DI_LAI': 418/600 frames
# Đang ghi 'DI_LAI': 419/600 frames
# Đang ghi 'DI_LAI': 420/600 frames
# Đang ghi 'DI_LAI': 421/600 frames
# Đang ghi 'DI_LAI': 422/600 frames
# Đang ghi 'DI_LAI': 423/600 frames
# Đang ghi 'DI_LAI': 424/600 frames
# Đang ghi 'DI_LAI': 425/600 frames
# Đang ghi 'DI_LAI': 426/600 frames
# Đang ghi 'DI_LAI': 427/600 frames
# Đang ghi 'DI_LAI': 428/600 frames
# Đang ghi 'DI_LAI': 429/600 frames
# Đang ghi 'DI_LAI': 430/600 frames
# Đang ghi 'DI_LAI': 431/600 frames
# Đang ghi 'DI_LAI': 432/600 frames
# Đang ghi 'DI_LAI': 433/600 frames
# Đang ghi 'DI_LAI': 434/600 frames
# Đang ghi 'DI_LAI': 435/600 frames
# Đang ghi 'DI_LAI': 436/600 frames
# Đang ghi 'DI_LAI': 437/600 frames
# Đang ghi 'DI_LAI': 438/600 frames
# Đang ghi 'DI_LAI': 439/600 frames
# Đang ghi 'DI_LAI': 440/600 frames
# Đang ghi 'DI_LAI': 441/600 frames
# Đang ghi 'DI_LAI': 442/600 frames
# Đang ghi 'DI_LAI': 443/600 frames
# Đang ghi 'DI_LAI': 444/600 frames
# Đang ghi 'DI_LAI': 445/600 frames
# Đang ghi 'DI_LAI': 446/600 frames
# Đang ghi 'DI_LAI': 447/600 frames
# Đang ghi 'DI_LAI': 448/600 frames
# Đang ghi 'DI_LAI': 449/600 frames
# Đang ghi 'DI_LAI': 450/600 frames
# Đang ghi 'DI_LAI': 451/600 frames
# Đang ghi 'DI_LAI': 452/600 frames
# Đang ghi 'DI_LAI': 453/600 frames
# Đang ghi 'DI_LAI': 454/600 frames
# Đang ghi 'DI_LAI': 455/600 frames
# Đang ghi 'DI_LAI': 456/600 frames
# Đang ghi 'DI_LAI': 457/600 frames
# Đang ghi 'DI_LAI': 458/600 frames
# Đang ghi 'DI_LAI': 459/600 frames
# Đang ghi 'DI_LAI': 460/600 frames
# Đang ghi 'DI_LAI': 461/600 frames
# Đang ghi 'DI_LAI': 462/600 frames
# Đang ghi 'DI_LAI': 463/600 frames
# Đang ghi 'DI_LAI': 464/600 frames
# Đang ghi 'DI_LAI': 465/600 frames
# Đang ghi 'DI_LAI': 466/600 frames
# Đang ghi 'DI_LAI': 467/600 frames
# Đang ghi 'DI_LAI': 468/600 frames
# Đang ghi 'DI_LAI': 469/600 frames
# Đang ghi 'DI_LAI': 470/600 frames
# Đang ghi 'DI_LAI': 471/600 frames
# Đang ghi 'DI_LAI': 472/600 frames
# Đang ghi 'DI_LAI': 473/600 frames
# Đang ghi 'DI_LAI': 474/600 frames
# Đang ghi 'DI_LAI': 475/600 frames
# Đang ghi 'DI_LAI': 476/600 frames
# Đang ghi 'DI_LAI': 477/600 frames
# Đang ghi 'DI_LAI': 478/600 frames
# Đang ghi 'DI_LAI': 479/600 frames
# Đang ghi 'DI_LAI': 480/600 frames
# Đang ghi 'DI_LAI': 481/600 frames
# Đang ghi 'DI_LAI': 482/600 frames
# Đang ghi 'DI_LAI': 483/600 frames
# Đang ghi 'DI_LAI': 484/600 frames
# Đang ghi 'DI_LAI': 485/600 frames
# Đang ghi 'DI_LAI': 486/600 frames
# Đang ghi 'DI_LAI': 487/600 frames
# Đang ghi 'DI_LAI': 488/600 frames
# Đang ghi 'DI_LAI': 489/600 frames
# Đang ghi 'DI_LAI': 490/600 frames
# Đang ghi 'DI_LAI': 491/600 frames
# Đang ghi 'DI_LAI': 492/600 frames
# Đang ghi 'DI_LAI': 493/600 frames
# Đang ghi 'DI_LAI': 494/600 frames
# Đang ghi 'DI_LAI': 495/600 frames
# Đang ghi 'DI_LAI': 496/600 frames
# Đang ghi 'DI_LAI': 497/600 frames
# Đang ghi 'DI_LAI': 498/600 frames
# Đang ghi 'DI_LAI': 499/600 frames
# Đang ghi 'DI_LAI': 500/600 frames
# Đang ghi 'DI_LAI': 501/600 frames
# Đang ghi 'DI_LAI': 502/600 frames
# Đang ghi 'DI_LAI': 503/600 frames
# Đang ghi 'DI_LAI': 504/600 frames
# Đang ghi 'DI_LAI': 505/600 frames
# Đang ghi 'DI_LAI': 506/600 frames
# Đang ghi 'DI_LAI': 507/600 frames
# Đang ghi 'DI_LAI': 508/600 frames
# Đang ghi 'DI_LAI': 509/600 frames
# Đang ghi 'DI_LAI': 510/600 frames
# Đang ghi 'DI_LAI': 511/600 frames
# Đang ghi 'DI_LAI': 512/600 frames
# Đang ghi 'DI_LAI': 513/600 frames
# Đang ghi 'DI_LAI': 514/600 frames
# Đang ghi 'DI_LAI': 515/600 frames
# Đang ghi 'DI_LAI': 516/600 frames
# Đang ghi 'DI_LAI': 517/600 frames
# Đang ghi 'DI_LAI': 518/600 frames
# Đang ghi 'DI_LAI': 519/600 frames
# Đang ghi 'DI_LAI': 520/600 frames
# Đang ghi 'DI_LAI': 521/600 frames
# Đang ghi 'DI_LAI': 522/600 frames
# Đang ghi 'DI_LAI': 523/600 frames
# Đang ghi 'DI_LAI': 524/600 frames
# Đang ghi 'DI_LAI': 525/600 frames
# Đang ghi 'DI_LAI': 526/600 frames
# Đang ghi 'DI_LAI': 527/600 frames
# Đang ghi 'DI_LAI': 528/600 frames
# Đang ghi 'DI_LAI': 529/600 frames
# Đang ghi 'DI_LAI': 530/600 frames
# Đang ghi 'DI_LAI': 531/600 frames
# Đang ghi 'DI_LAI': 532/600 frames
# Đang ghi 'DI_LAI': 533/600 frames
# Đang ghi 'DI_LAI': 534/600 frames
# Đang ghi 'DI_LAI': 535/600 frames
# Đang ghi 'DI_LAI': 536/600 frames
# Đang ghi 'DI_LAI': 537/600 frames
# Đang ghi 'DI_LAI': 538/600 frames
# Đang ghi 'DI_LAI': 539/600 frames
# Đang ghi 'DI_LAI': 540/600 frames
# Đang ghi 'DI_LAI': 541/600 frames
# Đang ghi 'DI_LAI': 542/600 frames
# Đang ghi 'DI_LAI': 543/600 frames
# Đang ghi 'DI_LAI': 544/600 frames
# Đang ghi 'DI_LAI': 545/600 frames
# Đang ghi 'DI_LAI': 546/600 frames
# Đang ghi 'DI_LAI': 547/600 frames
# Đang ghi 'DI_LAI': 548/600 frames
# Đang ghi 'DI_LAI': 549/600 frames
# Đang ghi 'DI_LAI': 550/600 frames
# Đang ghi 'DI_LAI': 551/600 frames
# Đang ghi 'DI_LAI': 552/600 frames
# Đang ghi 'DI_LAI': 553/600 frames
# Đang ghi 'DI_LAI': 554/600 frames
# Đang ghi 'DI_LAI': 555/600 frames
# Đang ghi 'DI_LAI': 556/600 frames
# Đang ghi 'DI_LAI': 557/600 frames
# Đang ghi 'DI_LAI': 558/600 frames
# Đang ghi 'DI_LAI': 559/600 frames
# Đang ghi 'DI_LAI': 560/600 frames
# Đang ghi 'DI_LAI': 561/600 frames
# Đang ghi 'DI_LAI': 562/600 frames
# Đang ghi 'DI_LAI': 563/600 frames
# Đang ghi 'DI_LAI': 564/600 frames
# Đang ghi 'DI_LAI': 565/600 frames
# Đang ghi 'DI_LAI': 566/600 frames
# Đang ghi 'DI_LAI': 567/600 frames
# Đang ghi 'DI_LAI': 568/600 frames
# Đang ghi 'DI_LAI': 569/600 frames
# Đang ghi 'DI_LAI': 570/600 frames
# Đang ghi 'DI_LAI': 571/600 frames
# Đang ghi 'DI_LAI': 572/600 frames
# Đang ghi 'DI_LAI': 573/600 frames
# Đang ghi 'DI_LAI': 574/600 frames
# Đang ghi 'DI_LAI': 575/600 frames
# Đang ghi 'DI_LAI': 576/600 frames
# Đang ghi 'DI_LAI': 577/600 frames
# Đang ghi 'DI_LAI': 578/600 frames
# Đang ghi 'DI_LAI': 579/600 frames
# Đang ghi 'DI_LAI': 580/600 frames
# Đang ghi 'DI_LAI': 581/600 frames
# Đang ghi 'DI_LAI': 582/600 frames
# Đang ghi 'DI_LAI': 583/600 frames
# Đang ghi 'DI_LAI': 584/600 frames
# Đang ghi 'DI_LAI': 585/600 frames
# Đang ghi 'DI_LAI': 586/600 frames
# Đang ghi 'DI_LAI': 587/600 frames
# Đang ghi 'DI_LAI': 588/600 frames
# Đang ghi 'DI_LAI': 589/600 frames
# Đang ghi 'DI_LAI': 590/600 frames
# Đang ghi 'DI_LAI': 591/600 frames
# Đang ghi 'DI_LAI': 592/600 frames
# Đang ghi 'DI_LAI': 593/600 frames
# Đang ghi 'DI_LAI': 594/600 frames
# Đang ghi 'DI_LAI': 595/600 frames
# Đang ghi 'DI_LAI': 596/600 frames
# Đang ghi 'DI_LAI': 597/600 frames
# Đang ghi 'DI_LAI': 598/600 frames
# Đang ghi 'DI_LAI': 599/600 frames
# Đang ghi 'DI_LAI': 600/600 frames
# Đã thu thập đủ 600 frames cho 'DI_LAI'!
# Dữ liệu đã lưu thành công!
